# %%
# Importing pandas library as pd for data manipulation
import pandas as pd
#mporting numpy for numerical operations
import numpy as np
#Importing seaborn for statistical data visualization
import seaborn as sns
#Importing matplotlib for plotting graphs and charts
import matplotlib.pyplot as plt

# %%
# read csv file to get data sets
red_wine = pd.read_csv('Dataset/winequality-red.csv', sep=";")
white_wine = pd.read_csv('Dataset/winequality-white.csv' , sep=";")

# %%
from IPython.display import display,HTML
display(HTML("<h2 style='text-align: center; font-weight: bold; color:red; '>RED WINE</h2>"))
display(HTML("<h2 style='text-align: center; font-weight: bold; color:green; '>------ 10 first records-------</h2>"))
display(red_wine.head(10))
display(HTML("<h2 style='text-align: center; font-weight:bold; color:green; '>-------10 last records--------</h2>"))
display(red_wine.tail(10))
# Out:
# <h2 style='text-align: center; font-weight: bold; color:red; '>RED WINE</h2>
# <h2 style='text-align: center; font-weight: bold; color:green; '>------ 10 first records-------</h2>
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# ...

# %%
display(HTML("<h2 style='text-align:center; font-weight:bold; color:green; '>WHITE WINE</h2>"))
display(HTML("<h2 style='text-align:center; font-weight:bold; color:green; '>------ 10 first records------</h2>"))
display(white_wine.head(10))
display(HTML("<h2 style= 'text-align:center; font-weight:bold; color:green; '>------ 10 last records------</h2>"))
display(white_wine.tail(10))
# Out:
# <h2 style='text-align:center; font-weight:bold; color:green; '>WHITE WINE</h2>
# <h2 style='text-align:center; font-weight:bold; color:green; '>------ 10 first records------</h2>
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# ...

# %%
# printing columns with number of null values 
display(HTML("<h2 style='text-align: left; font-weight: bold; color:red; '>RED WINE</h2>"))

ncs = red_wine.isna().sum()
html_output =""
for column, count in ncs.items():
    if count == 0:
        print(f"\033[1;32m {column}, {count}\033[0m")
# Out:
# <h2 style='text-align: left; font-weight: bold; color:red; '>RED WINE</h2>
#  fixed acidity, 0
#  volatile acidity, 0
#  citric acid, 0
#  residual sugar, 0
#  chlorides, 0
#  free sulfur dioxide, 0
#  total sulfur dioxide, 0
#  density, 0
#  pH, 0
#  sulphates, 0
#  alcohol, 0
#  quality, 0

# %%
# printing columns with number of null values 
display(HTML("<h2 style='text-align: left; font-weight: bold; color:green; '>WHITE WINE</h2>"))
white_wine.isna().sum()
# Out:
# <h2 style='text-align: left; font-weight: bold; color:green; '>WHITE WINE</h2>
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# red_wine -- columns with number of rows and datatypes
# number of rows and columns 
display(HTML("<h2 style='text-align: left; font-weight: bold; color:red; '>RED WINE</h2>"))

display(red_wine.info())
display(f"number of rows and columns :{red_wine.shape}")
print(f"number of rows and columns :{red_wine.shape}")
# Out:
# <h2 style='text-align: left; font-weight: bold; color:red; '>RED WINE</h2>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
# ...

# %%
# white_wine -- columns with number of rows and datatypes
# number of rows and columns

display(HTML("<h2 style='text-align: left; font-weight: bold; color:green; '>WHITE WINE</h2>"))
display(white_wine.info())
display(f"Number of rows and columns: {white_wine.shape}")
# Out:
# <h2 style='text-align: left; font-weight: bold; color:green; '>WHITE WINE</h2>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# None
# ...

# %%
# red_wine ---- checking Descriptive Statistics
display(HTML("<h2 style='text-align: left; font-weight: bold; color:red; '>RED WINE</h2>"))
red_wine.describe().round(2)
# Out:
# <h2 style='text-align: left; font-weight: bold; color:red; '>RED WINE</h2>
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        1599.00           1599.00      1599.00         1599.00
# mean            8.32              0.53         0.27            2.54
# std             1.74              0.18         0.19            1.41
# min             4.60              0.12         0.00            0.90
# 25%             7.10              0.39         0.09            1.90
# 50%             7.90              0.52         0.26            2.20
# 75%             9.20              0.64         0.42            2.60
# max            15.90              1.58         1.00           15.50
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    1599.00              1599.00               1599.00  1599.00  1599.00
# mean        0.09                15.87                 46.47     1.00     3.31
# ...

# %%
# white_wine ---- checking Descriptive Statistics
display(HTML("<h2 style='text-align: left; font-weight: bold; color:green; '>WHITE WINE</h2>"))
white_wine.describe().round(2)
# Out:
# <h2 style='text-align: left; font-weight: bold; color:green; '>WHITE WINE</h2>
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        4898.00           4898.00      4898.00         4898.00
# mean            6.85              0.28         0.33            6.39
# std             0.84              0.10         0.12            5.07
# min             3.80              0.08         0.00            0.60
# 25%             6.30              0.21         0.27            1.70
# 50%             6.80              0.26         0.32            5.20
# 75%             7.30              0.32         0.39            9.90
# max            14.20              1.10         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    4898.00              4898.00               4898.00  4898.00  4898.00
# mean        0.05                35.31                138.36     0.99     3.19
# ...

# %%
# red wine
# we are creating a new column called "quality_label", we define a range and associate that range with a label

red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(
    red_wine['quality_label'], categories=['low', 'medium', 'high'], ordered= True)
display(red_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#white-wine

white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 
else'medium'
if value <= 7 
else'high')

# here we are transforming these labels into categrical data type(specific to pandas) instead of simple string
white_wine['quality_label'] = pd.Categorical(
    white_wine['quality_label'], categories=['low','medium','high'],ordered= True)
display(white_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# white-wine 
if 'quality' in white_wine.columns and 'quality_label' in white_wine.columns:
    hq = white_wine.loc[white_wine['quality_label'] =='high' ,['quality','quality_label']]
    #hq.apply(lambda row:  print(f"{row['quality']}  {row['quality_label']}"), axis= 1)
    print(hq.to_string(index=False, col_space= 15))
else:
    print("columns 'quality' and 'quality_label")
# Out:
#         quality   quality_label
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               8            high
#               9            high
#               8            high
#               8            high
#               8            high
#               9            high
#               9            high
#               8            high
# ...

# %%
# red-wine--- check for unique values 
red_wine.nunique()
red_wine.round(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9       0.08
# 1               7.8              0.88         0.00             2.6       0.10
# 2               7.8              0.76         0.04             2.3       0.09
# 3              11.2              0.28         0.56             1.9       0.08
# 4               7.4              0.70         0.00             1.9       0.08
# ...             ...               ...          ...             ...        ...
# 1594            6.2              0.60         0.08             2.0       0.09
# 1595            5.9              0.55         0.10             2.2       0.06
# 1596            6.3              0.51         0.13             2.3       0.08
# 1597            5.9              0.64         0.12             2.0       0.08
# 1598            6.0              0.31         0.47             3.6       0.07
#
# ...

# %%
# white-wine---- check for unique values 

white_wine.nunique()
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# quality_label             3
# dtype: int64

# %%
# red-wine

red_wine['quality'].value_counts()
red_wine.sort_values(by='quality_label')
display(red_wine['quality'].value_counts() , red_wine['quality_label'].value_counts())
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64
# medium    837
# low       744
# high       18
# Name: quality_label, dtype: int64

# %%
#red_wine.columns
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  quality_label         1599 non-null   category
# dtypes: category(1), float64(11), int64(1)
# memory usage: 151.7 KB

# %% [markdown]
# # Wine Analysis report for both data sets(red_wine and white_wine)
#
# ##### Fixed Acidity: Acidity that doesn’t evaporate. Ideal Range [ red_wine(3.0-5.5 g/L) , white_wine(5.5-7.5 g/L)]
# ##### Volatile Acidity: Acidity that evaporates; affects aroma. Ideal Range [ red_wine(0.2-0.6 g/L) , white_wine(0.2-0.4 g/L)]
# ##### Citric Acid: This can give wines a fresher taste.  Ideal Range [ red_wine(0-0.3 g/L) , white_wine(0.3-0.7 g/L)]
# ##### Residual Sugar: Remaining sugar after fermentation; affects sweetness. Ideal Range [ red_wine(0-2 g/L) , white_wine(1-6 g/L)]
# ##### Chlorides: Saltiness level in wine. Ideal Range [ red_wine(0.01-0.08 g/L) , white_wine(0.01 - 0.06 g/L)]
# ##### Free Sulfur Dioxide & Total Sulfur Dioxide: Preservatives used to prevent spoilage.FSD[ red_wine(10-50 mg/L) , white_wine(20-50 mg/L)] and TSD [ red_wine(20-100 mg/L) , white_wine(30-150 mg/L)]
# ##### Density: Linked to sugar and alcohol levels. Ideal Range [ red_wine(0.990-1.010 g/mL) , white_wine(0.990-1000 g/mL)]
# ##### pH: Acidity level; lower pH means higher acidity. Ideal Range [ red_wine(3.3-3.7 ) , white_wine(3.0-3.4)]
# ##### Sulfates: These can add to the wine’s stability and flavor. Ideal Range [ red_wine(0.3-0.6 g/L) , white_wine(0.3-0.7 g/L)]
# ##### Alcohol: Alcohol percentage. Ideal Range [ red_wine(12% - 14% ) , white_wine(10% - 13%)]
# ##### Quality: Rating of wine quality (usually from 0-10). Ideal Range [ red_wine(7-10 ) , white_wine(7-10)]

# %%
# concat two data sets using concat operation 
col_alis = {
    'fixed acidity':'FAC', 'volatile acidity':'VAC', 'citric acid':'CAC', 'residual sugar':'RS',
       'chlorides':'CH', 'free sulfur dioxide':'FSD', 'total sulfur dioxide':'TSD', 'density':'DS',
       'pH':'PH', 'sulphates':'SLP', 'alcohol':'ALC', 'quality':'Q', 'quality_label':'QL'
}
red_df = red_wine.copy()
white_df = white_wine.copy()

red_df.rename(columns= col_alis , inplace= True)
white_df.rename(columns=col_alis, inplace= True)

red_d = red_df.describe().round(2)
white_d = white_df.describe().round(2)
pd.concat([red_d  ,white_d], keys=['red wine', 'white wine'])
# Out:
#                       FAC      VAC      CAC       RS       CH      FSD  \
# red wine   count  1599.00  1599.00  1599.00  1599.00  1599.00  1599.00
#            mean      8.32     0.53     0.27     2.54     0.09    15.87
#            std       1.74     0.18     0.19     1.41     0.05    10.46
#            min       4.60     0.12     0.00     0.90     0.01     1.00
#            25%       7.10     0.39     0.09     1.90     0.07     7.00
#            50%       7.90     0.52     0.26     2.20     0.08    14.00
#            75%       9.20     0.64     0.42     2.60     0.09    21.00
#            max      15.90     1.58     1.00    15.50     0.61    72.00
# white wine count  4898.00  4898.00  4898.00  4898.00  4898.00  4898.00
#            mean      6.85     0.28     0.33     6.39     0.05    35.31
#            std       0.84     0.10     0.12     5.07     0.02    17.01
#            min       3.80     0.08     0.00     0.60     0.01     2.00
# ...

# %% [markdown]
# ###### red_wine (1599, 13) ---- number of rows and columns
# ###### white_wine (4898, 13)----- number of rows and columns
# ##### volatile acidity : the mean of volatile acidity is high in red_wine than white_wine
#      - red_wine: 0.53
#      - white_wine: 0.28
# ##### citric acid :  based on the mean values , white wine has a higher citric acid content on average than red wine, regardless of row count
#      - red_wine:0.27
#      - white_wine: 0.33
# ##### residual sugar : based on the values, white_wine has higher residual sugar than red wine
#      - red_wine:2.54
#      - white_wine:6.39
# ##### chlorides :  red wine has 4% more chlorides than white wine
#      - red_wine:0.09
#      - white_wine:0.05
# ##### density : Red wine has a density closer to water (1.00), while white wine's density is slightly lower (0.99). While density can provide some insight into wine      composition, balance in wine is influenced by multiple factors beyond density alone, such as acidity, sweetness, tannins, and alcohol content
#      - red_wine:1.00
#      - white_wine:0.99
# ##### pH : Red wine typically has higher pH than white wine , make it taste softer and rounder, while white wine's lower pH gives it a crisper, more acid profile.
#      - red_wine:3.31
#      - white_wine:3.19
# ##### sulphates : red_wine has more sulphates than white wine
#      - red_wine:0.66
#      - white_wine:0.49
# ##### alcohol: the percentage of alcohol is higher in white wine than read wine
#      - red_wine:10.42
#      - white_wine:10.51

# %%
print("red_wine",red_wine.shape)
print("white_wine", white_wine.shape)
# Out:
# red_wine (1599, 13)
# white_wine (4898, 13)

# %%
# Comparison of the number of red and white wines
# only number of rows from each data sets
x = len(red_wine.index)  
y = len(white_wine.index)

labels = 'red_wine', 'white_wine'

# size of our pyplot
sizes = [x, y]

# adding colors
colors = ['red', 'lightblue']

 # only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0.1) 

# create pie plot
fig1, ax1 = plt.subplots(figsize=(8,6))
ax1.pie(sizes, explode=explode, autopct='%1.1f%%',  shadow=True, startangle=100, colors=colors) # label = labels
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle."""
#plt.title('Comparison of the number of red and white wines')
ax1.set_title('Comparison of the number of red and white wines',
              fontsize=14, color='lightblue')  #
# Remove the background color of the axes and figure
ax1.set_facecolor('none')  # Transparent background for the axes
fig1.patch.set_facecolor('none')  # Transparent background for the figure

# add legend 
plt.legend(loc = 'upper left', labels = labels , edgecolor ='none')

# add annotations 
plt.annotate(f"Total wine samples : '{x+y}' ", xy=(1, 1), fontsize = 16, ha = 'center' , va = 'center', color ='lightblue')
plt.tight_layout()
plt.show()

# %% [markdown]
# ######

# %%
# distrabution of qualities by type in Red_wine and white wine 

#plt.figure(figsize=( 4, 4))
#sns.countplot(x=red_wine["quality_label"], color="red")
#plt.title("Quality Label" , color ='red')
#plt.xlabel("Quality")
#plt.ylabel("number of rows")
#plt.show() 

fig1 , axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5) , sharey=True)
sns.histplot(data=red_wine, x='quality_label', color='red', shrink=0.8, ax=axes[0]).set(title='Red Wine')
sns.histplot(data = white_wine, x='quality_label', color='lightblue', shrink=.8, ax=axes[1]).set(title ='White Wine')
axes[0].set_xlabel("Quality", color = 'red', fontweight ='bold')
axes[0].set_ylabel("Count", color='red' ,fontweight = 'bold')
axes[1].set_xlabel("Quality", color='blue' , fontweight='bold')
#axes[1].set_ylabel("Count", color='lightblue')
plt.suptitle("Distrabution of qualities by type in wines", color="red" ,fontweight ='bold' )



plt.show()
